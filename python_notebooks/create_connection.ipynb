# %%
# Databricks notebook source
# MAGIC %md
# MAGIC ## Mount the following data lake storage gen2 containers
# MAGIC 1. raw
# MAGIC 2. processed
# MAGIC 3. lookup

# COMMAND ----------

# MAGIC %md
# MAGIC ### Set-up the configs
# MAGIC #### Please update the following 
# MAGIC - application-id
# MAGIC - service-credential
# MAGIC - directory-id

# %%
# COMMAND ----------

configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": "b784d8c1-45e4-4dfc-b746-58927d67e826",
           "fs.azure.account.oauth2.client.secret": "WF58Q~Dv.KadjdZ~L.tgIQHy5gHWEMdQIoSGKaT9",
           "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/75f54bd9-7a2a-4e7b-b802-7117416c646e/oauth2/token"}

# %%
# COMMAND ----------

dbutils.fs.mount(
  source = "abfss://azureraw@azurepractice58.dfs.core.windows.net/",
  mount_point = "/mnt/azurepractice58/azureraw",
  extra_configs = configs)
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# <command-3422162067834032> in <module>
#       1 # COMMAND ----------
#       2
# ----> 3 dbutils.fs.mount(
#       4   source = "abfss://azureraw@azurepractice58.dfs.core.windows.net/",
#       5   mount_point = "/mnt/azurepractice58/azureraw",
#
# /databricks/python_shell/dbruntime/dbutils.py in f_with_exception_handling(*args, **kwargs)
#     387                     exc.__context__ = None
#     388                     exc.__cause__ = None
# --> 389                     raise exc
#     390
#     391             return f_with_exception_handling
#
# ExecutionError: An error occurred while calling o406.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/azurepractice58/azureraw; nested exception is:
# ...

# %%
# COMMAND ----------

dbutils.fs.mount(
  source = "abfss://azureprocessed@azurepractice58.dfs.core.windows.net/",
  mount_point = "/mnt/azurepractice58/azureprocessed",
  extra_configs = configs)
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# <command-3422162067834033> in <module>
#       1 # COMMAND ----------
#       2
# ----> 3 dbutils.fs.mount(
#       4   source = "abfss://azureprocessed@azurepractice58.dfs.core.windows.net/",
#       5   mount_point = "/mnt/azurepractice58/azureprocessed",
#
# /databricks/python_shell/dbruntime/dbutils.py in f_with_exception_handling(*args, **kwargs)
#     387                     exc.__context__ = None
#     388                     exc.__cause__ = None
# --> 389                     raise exc
#     390
#     391             return f_with_exception_handling
#
# ExecutionError: An error occurred while calling o406.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/azurepractice58/azureprocessed; nested exception is:
# ...

# %%
dbutils.fs.ls("/mnt/azurepractice58/azureraw")
# Out:
# Out[26]: [FileInfo(path='dbfs:/mnt/azurepractice58/azureraw/raw/', name='raw/', size=0, modificationTime=1670871750000)]

# %%
dbutils.fs.ls("/mnt/azurepractice58/azureprocessed")
# Out:
# Out[27]: [FileInfo(path='dbfs:/mnt/azurepractice58/azureprocessed/processed/', name='processed/', size=0, modificationTime=1670872366000)]
